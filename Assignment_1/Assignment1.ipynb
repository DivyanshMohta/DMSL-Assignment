# %%
#  Perform the following operations using R/Python on suitable data sets:
#  a. read data from different formats(like csv, xls)
#  b. indexing and selecting data, sort data, describe attributes of data
#  c. checking data types of each column
#  d. counting unique values of data
#  e. format of each column
#  f. converting variable data type (e.g. from long to short, vice versa)
#  g. identifying missing values and fill in the missing values

# %%
import pandas as pd
import numpy as np

# %%
#  a. read data from different formats(like csv, xls)

Heart_pat = pd.read_csv("/content/Heart.csv")
Heart_pat.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %%
#  b. indexing and selecting data, sort data, describe attributes of data

Selected_arr = Heart_pat.iloc[2:7,1:6]
Selected_arr
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 93    44    0    nonanginal     108   141
# 273   71    0  asymptomatic     112   149
# 232   49    1    nonanginal     118   149
# 295   41    1    nontypical     120   157
# 169   45    0    nontypical     112   160

# %%
BP = Selected_arr.sort_values(['Age'], axis=0,inplace=True)
Selected_arr
# Out:
#      Age  Sex     ChestPain  RestBP  Chol
# 295   41    1    nontypical     120   157
# 93    44    0    nonanginal     108   141
# 169   45    0    nontypical     112   160
# 232   49    1    nonanginal     118   149
# 273   71    0  asymptomatic     112   149

# %%
Heart_pat.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
#  c. checking data types of each column
Heart_pat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 303 entries, 202 to 152
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 37.9+ KB

# %%
#  d. counting unique values of data
unique_value = Heart_pat["Age"].nunique()
print(unique_value)
# Out:
# 41

# %%
#  e. format of each column
Heart_pat.applymap(type)
# Out:
#         Unnamed: 0            Age            Sex      ChestPain  \
# 202  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 300  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 93   <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 273  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 232  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# ..             ...            ...            ...            ...
# 173  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 121  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 181  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 48   <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 152  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
#
#             RestBP           Chol            Fbs        RestECG  \
# 202  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 300  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# ...

# %%
#  f. converting variable data type (e.g. from long to short, vice versa)
Heart_pat['Oldpeak'] = Heart_pat['Oldpeak'].astype(int)
Heart_pat.applymap(type)
# Out:
#         Unnamed: 0            Age            Sex      ChestPain  \
# 202  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 300  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 93   <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 273  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 232  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# ..             ...            ...            ...            ...
# 173  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 121  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 181  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 48   <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
# 152  <class 'int'>  <class 'int'>  <class 'int'>  <class 'str'>
#
#             RestBP           Chol            Fbs        RestECG  \
# 202  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# 300  <class 'int'>  <class 'int'>  <class 'int'>  <class 'int'>
# ...

# %%
#  g. identifying missing values and fill in the missing values
Heart_pat.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64
